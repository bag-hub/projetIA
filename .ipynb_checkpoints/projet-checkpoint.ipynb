# %% [markdown]
#                             PROJET INTRODUCTION A L'INTELLIGENCE ARTIFICIELLE
#
# Réalisé en Binome par :   GUEYE A. BAYE & N'TCHAM KOMINA ROGER
#
# NB : Comme indication, dans chaques parties, du projets, nous allons apporté des explication de ce que nous faisons et du code de cette action. Cette seance 1 est scindé en 3 phases dans la suite de notre travail.

# %% [markdown]
# SEANCE 1 : CHARGEMENT DES DONNEES ET EXPLORATIONS
# Ici nous avons choisis 5 classes comme le demande le sujet dans le jeu de données CIFAR-10. Ces classes sont
#
#                             --AUTOMOBILE---CAT---DOG---HORSE---SHIP.

# %% [markdown]
# Phase 1 : Cette section charge les fichiers CIFAR‑10 bruts, extrait les images et labels, puis applique un filtrage pour ne conserver que les cinq classes choisies, ce qui permet de constituer un sous‑ensemble cohérent et adapté aux contraintes du projet.

# %%
                        
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay


#1---Chargement des données de travail
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

batches_meta = unpickle("./cifar-10-batches-py/batches.meta")
label_names = batches_meta[b'label_names']

image_list = []
label_list = []
filename_list = []

for i in range(1,6):
    batch_file = unpickle(f"./cifar-10-batches-py/data_batch_{i}")
    data = batch_file[b'data']
    labels = batch_file[b'labels']
    filenames = batch_file[b'filenames']

    tab_label = np.array(labels)
    tab_filenames = np.array(filenames)
    
    filtrage = (tab_label == 1) | (tab_label == 3) | (tab_label == 5) | (tab_label == 7) | (tab_label == 8)

    image_list.append(data[filtrage])
    label_list.append(tab_label[filtrage])

    for fname in tab_filenames[filtrage]:
        filename_list.append(fname.decode())

# %% [markdown]
#  Phase 2 : Dans cette phase, nous structurons le dataset en regroupant par concatenation les images filtrées provenant des différents batches, puis nous construisons un DataFrame contenant les identifiants, labels et noms de classes comme demandé dans le sujet. Nous réalisons ensuite une première exploration visuelle du jeu de données, à travers la représentation graphique de la répartition des classes sélectionnées et l’affichage d’exemples d’images correspondantes.
#  Conformément aux consignes, nous limitons ensuite notre ensemble à 10 000 images (dont 8 000 destinées à l’entraînement et 2 000 au test).

# %%
regroup_img = np.concatenate(image_list)
regroup_label = np.concatenate(label_list)
regroup_img = regroup_img[:10000]
regroup_label = regroup_label[:10000]

filename_list = filename_list[:10000]
classe_corresp = []
for cl in regroup_label:
    classe = label_names[cl].decode()
    classe_corresp.append(classe)

dataframe = pd.DataFrame({"Identifiant": np.arange(len(regroup_img)),
                          "Label": regroup_label, 
                          "Classe" : classe_corresp })

print("Le dataFrame de notre jeu de donnée est : \n", dataframe)

print("Visualisation sous la forme d'une diagramme en barre :\n")
comptage = dataframe["Classe"].value_counts()
print("\n", comptage)

comptage.plot(kind="bar", title="Répartition des classes", color = "red")
plt.show()

print("La constructuction des image de nos classes choisies sont : \n")
def convertir_image(image):
    conversion = image.reshape(3, 32, 32).transpose(1, 2, 0)
    return conversion

classes = ["automobile", "cat", "dog", "horse", "ship"]

fig, axes = plt.subplots(1, 5, figsize = (15, 5))

# AUTOMOBILE 
print("Construction de l'image AUTOMOBILE \n")
idx_auto = dataframe.index[dataframe["Classe"] == "automobile"][0] 
img_auto = convertir_image(regroup_img[idx_auto]) 
axes[0].imshow(img_auto) 
axes[0].set_title("Automobile")

# CAT
print("Construction de l'image CAT \n")
idx_cat = dataframe.index[dataframe["Classe"] == "cat"][0] 
img_cat = convertir_image(regroup_img[idx_cat]) 
axes[1].imshow(img_cat) 
axes[1].set_title("Cat")

#DOG
print("Construction de l'image DOG \n")
idx_dog = dataframe.index[dataframe["Classe"] == "dog"][0] 
img_dog = convertir_image(regroup_img[idx_dog]) 
axes[2].imshow(img_dog) 
axes[2].set_title("Dog")

#HORSE
print("Construction de l'image HORSE \n")
idx_horse = dataframe.index[dataframe["Classe"] == "horse"][0] 
img_horse = convertir_image(regroup_img[idx_horse]) 
axes[3].imshow(img_horse) 
axes[3].set_title("Horse") 

#SHIP
print("Construction de l'image SHIP \n")
idx_ship = dataframe.index[dataframe["Classe"] == "ship"][0] 
img_ship = convertir_image(regroup_img[idx_ship]) 
axes[4].imshow(img_ship) 
axes[4].set_title("Ship") 

plt.tight_layout()
plt.show()

# %% [markdown]
# Phase 3 :  Nous commencons ici l’évaluation du modèle de référence que nous entraînons à partir des pixels bruts des images. L’objectif est de mesurer sa capacité à reconnaître correctement les cinq classes sélectionnées, en utilisant d’abord l’accuracy comme indicateur global de performance, puis une matrice de confusion pour analyser plus finement les erreurs de classification.

# %%
test_batch = unpickle("./cifar-10-batches-py/test_batch")
test_data = test_batch[b'data']
test_labels = np.array(test_batch[b'labels'])

filtrage_test = (test_labels == 1) | (test_labels == 3) | (test_labels == 5) | (test_labels == 7) | (test_labels == 8)

X_test_raw = test_data[filtrage_test]
y_test = test_labels[filtrage_test]
X_test_raw = X_test_raw[:2000]
y_test = y_test[:2000]
X_train_norm = regroup_img / 255
X_test_norm = X_test_raw / 255

def entrainer_mlp(X, y):
    modele = MLPClassifier(
        hidden_layer_sizes=(100,),
        activation = 'relu',
        solver = 'adam',
        max_iter = 20,
        random_state = 42)
    modele.fit(X, y)
    return modele

mlp_ref = entrainer_mlp(X_train_norm, regroup_label)
y_pred = mlp_ref.predict(X_test_norm)

#Accuracy
score_acc = accuracy_score(y_test, y_pred)
print("l' Accuracy est donc \n: ", score_acc)

#matrice de confucion 
matrice = confusion_matrix(y_test, y_pred)
print("Matrice de confusion (nombres bruts) :\n", matrice)

# %% [markdown]
# Interpretation des resultats de la phase 3 :
#
#   *ANALYSE DE L'ACCURACY : L’évaluation du modèle MLP sur notre jeu de donnée entraîné  une accuracy de 0.6085, soit environ 60,85 % de bonnes prédictions sur les 2000 images du jeu de test filtré.
#
#   *ANALYSE DE LA MATRICE DE CONFUSION : La matrice de confusion montre que le modèle parvient à reconnaître une partie des images, mais qu’il commet encore de nombreuses erreurs entre certaines classes. Deux classes se distinguent par de bons résultats (plus de 260 et 320 prédictions correctes), tandis que d’autres sont nettement plus confondues entre elles, ce qui révèle des similarités visuelles difficiles à séparer avec des pixels bruts. Ces résultats confirment la nécessité d’améliorer la représentation des images dans les phases suivantes.

# %% [markdown]
# SEANCE 2: EXTRACTION DE CARACTERISTIQUE AVEC OpenCV
#
# L’objectif que nous dans cette partie est de construire une représentation plus informative et solide, en extrayant des caractéristiques visuelles de notre jeu de donnée relative à nos classes choisies
#
# Ici on a choisis comme caractéristique : COULEUR ET SEUILLAGE
#
# NB : On a choisis de découper cette partie en 3 phases

# %% [markdown]
# Phase 1 : Representation Visuelle de nos caractéristique (COULEUR ET SEUILLAGE)

# %% [markdown]
#             CARACTERISTIQUE COULEUR

# %%
import sys
print(sys.executable)
import cv2
print(cv2.__version__)

def caracteristiques_Couleur(image):
    img_base = convertir_image(image)
    img = cv2.cvtColor(img_base, cv2.COLOR_BGR2RGB) 
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    indice_couleur = [0, 1, 2]
    couleurs = ['r', 'g', 'b']

    for i in range(len(indice_couleur)):
        canal = indice_couleur[i]
        axes[i].hist(img[:, :, canal].flatten(), color = couleurs[i])
        axes[i].set_title(f"Histogramme {couleurs[i]}")
        axes[i].set_xlabel("Intensiter Pixel")
        axes[i].set_ylabel("Nbre de pixel ayant une intensité")
    plt.tight_layout()
    plt.show()

print("Visualisons la Caractéristique COULEUR")
label_rec = {}

for (i, name) in enumerate(label_names):
    classe = name.decode()
    label_rec[classe] = i

for choix in classes:
    code = label_rec[choix] 
    idx = np.where(regroup_label == code)[0][0]

    print(f"\nHistogrammes pour la classe : {choix}")
    caracteristiques_Couleur(regroup_img[idx])

# %% [markdown]
#             CARACTERISTIQUE SEUILLAGE

# %%
def caracteristiques_seuillage(image):
    img = convertir_image(image)
    gris = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    _,seuil = cv2.threshold(gris, 0, 255, cv2.THRESH_OTSU)

    noyau = np.ones((3, 3))
    ouverture = cv2.morphologyEx(seuil, cv2.MORPH_OPEN, noyau)
    fermeture = cv2.morphologyEx(seuil, cv2.MORPH_CLOSE, noyau)
    prop_avant = np.mean(seuil == 255)
    prop_ouv = np.mean(ouverture == 255)
    prop_ferm = np.mean(fermeture == 255)
    
    return (seuil, ouverture, fermeture, prop_avant, prop_ouv, prop_ferm)


print("Visualisons la Caracteristique SEUILLAGE")
for choix in classes:
    code = label_rec[choix] 
    idx = np.where(regroup_label == code)[0][0] # On prend la première image de la classe
    seuil, ouv, ferm, p_av, p_ou, p_fe = caracteristiques_seuillage(regroup_img[idx])
    fig, axes = plt.subplots(1, 4, figsize=(15, 4))
    
    axes[0].imshow(convertir_image(regroup_img[idx]))
    axes[0].set_title("Original:\n")
    
    axes[1].imshow(seuil, cmap='gray')
    axes[1].set_title(f"Seuillage Otsu: {p_av}")
    axes[1].axis("off")

    axes[2].imshow(ouv, cmap='gray')
    axes[2].set_title(f"Après Ouverture: {p_ou}")
    axes[2].axis("off")

    axes[3].imshow(ferm, cmap='gray')
    axes[3].set_title(f"Après Fermeture: {p_fe}")
    axes[3].axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Phase 2 : Extraction numérique des caractéristiques et Fusion des caractéristiques

# %% [markdown]
#                     Extraction numérique des histogrammes (R, G, B)
# NB : On a juste voulu ecrire 2 fonctions génériques  qui nous sera bénéfique dans la Phase 3.

# %%
def extraction_vecteur_couleur_et_morphologie(image):
    img_base = convertir_image(image)
    img = cv2.cvtColor(img_base, cv2.COLOR_BGR2RGB)
    
    hist_r = cv2.calcHist([img], [0], None, [256], [0, 256]).flatten()
    hist_g = cv2.calcHist([img], [1], None, [256], [0, 256]).flatten()
    hist_b = cv2.calcHist([img], [2], None, [256], [0, 256]).flatten()
    _, _, _, p_av, p_ou, p_fe = caracteristiques_seuillage(image)
    
    recup_couleur = np.concatenate([hist_r, hist_g, hist_b]) / (32*32)
    recup_morph = np.array([p_av, p_ou, p_fe])
    
    return (recup_couleur, recup_morph)

def fusionner(image):
    extrac_couleur, extrac_morphologie = extraction_vecteur_couleur_et_morphologie(image)
    tab = [extrac_couleur, extrac_morphologie]
    vecteur = np.concatenate(tab)
    return vecteur

# %% [markdown]
# Phase 3 : Construction des Matrices Caracteristiques et Comparaison Visuelle
#
# NB : Comparaison d'Histogramme moyen par classe...

# %%
print("Construction des matrices de caractéristiques...")

F_train = []
for img in regroup_img:
    F_train.append(fusionner(img))
F_train = np.array(F_train)

F_test = []
for img in X_test_raw:
    F_test.append(fusionner(img))
F_test = np.array(F_test)

print("F_train :", F_train.shape)
print("F_test  :", F_test.shape)

print("Visuel de la Phase 2 à Phase 3.")
axesX = np.arange(256)
for choix in classes:
    plt.figure(figsize = (12, 4))
    mask = (regroup_label == label_rec[choix])
    vecteur_moyen = np.mean(F_train[mask], 0)
    plt.bar(axesX, vecteur_moyen[0:256], color='r')
    plt.bar(axesX, vecteur_moyen[256:512], color='g')
    plt.bar(axesX, vecteur_moyen[512:768], color='b')
    
    plt.title(f"Histogramme moyen pour la classe : {choix}")
    plt.xlabel("Niveaux d'intensité (0 à 255)")
    plt.ylabel("Fréquence moyenne (normalisée)")
    plt.legend()
    plt.show()

# %% [markdown]
# SEANCE 3: Apprentissage et comparaison de modèles de classification
#  On a décider de séparer cette partie en 3 Phases.
#
#  NB : Ici nous on a choisi d'entrainer 2 modeles:
#
#      -MLP
#
#      -Arbre de decison

# %% [markdown]
# Phase 1 : Mise en place des modèles &définition des pipelines et Entrainement des Modeles (SVM, MLP, Arbres de Decision)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

print("Implementons donc les 2 modeles avec le pipeline et la normalisation, on a : \n")

modeleMLP = Pipeline([('Normalisation', StandardScaler()),
                     ('modele', MLPClassifier(hidden_layer_sizes=(100,), 
                             activation='relu', 
                             solver='adam', 
                             max_iter=50,      
                             random_state=42))])
modeleMLP.fit(F_train, regroup_label)

modeleArbredeDecision = Pipeline([
    ('Normalisation', StandardScaler()),
    ('modele', DecisionTreeClassifier(random_state=42))])
modeleArbredeDecision.fit(F_train, regroup_label);

# %% [markdown]
# Phase 2 : Construction des Hyperparametre de Recherche puis EVALUATION ET COMPARAISON DES MODELES.

# %%
def recherche_HyperParametre(X_entrainement, y_entrainement):
    lineaire = 'relu'
    hyperbole = 'tanh'
    transparent = 'identity'
    parametre_activation = [lineaire, hyperbole, transparent]

    grille = {'modele__activation': parametre_activation}
    recherche_HypPar = GridSearchCV(modeleMLP, grille, cv = 3)

    recherche_HypPar.fit(X_entrainement, y_entrainement)
    estimateur = recherche_HypPar.best_estimator_
    return estimateur

modeleMLP_optimise = recherche_HyperParametre(F_train, regroup_label)

score_mlp = modeleMLP_optimise.score(F_test, y_test)
score_arbre = modeleArbredeDecision.score(F_test, y_test)
print(f"\n Precision MLPOptimiser : {score_mlp}")
print(f"Precision Arbre de Decision : {score_arbre}")

recup_dataframe_resultat = pd.DataFrame({
    'Algorithme': ['MLP (Optimisé)', 'Arbre de Décision'],
    'Accuracy': [score_mlp, score_arbre]})
print(recup_dataframe_resultat)

recup_dataframe_resultat.to_csv("comparaison_modeles_seance3.csv", index=False)
print(recup_dataframe_resultat)

# %% [markdown]
# SEANCE 4:  ANALYSE DES ERREURS ET AMELIORATION
#
# Dans cette partie, on est dans la suite logique de la seance 3 en fait ..., ayant calculer le score Accuracy des 3 modeles (MLPOptimiser, SVM et Arbre de Decision), le modele qui est meilleur est celle qui a l'accuraccy la plus elévé, dans ce sens on d'apres la seance3 que ce sera le MLPOptimiser qui sera le meilleur modele de notre jeu de donné de test. En restant dans la ligne de notre sujet, nous allons maintenant analyser les erreurs commises par ce modèle, identifier les classes les plus confondues, puis proposer une amélioration simple afin d’observer son impact sur les performances finales
#
# NB :  Cette Partie sera decoupé en 3 Phases et Analyse à faire au final.

# %% [markdown]
# Phase 1 : Identification des erreurs du modèle
#
# Cette phase nous permettra d'Obtenir les prédictions du MLP optimisé, identifier les indices correspondant aux erreurs de classification, puis afficher quelques images mal classées pour visualiser les confusions du modèle.

# %%
y_pred_final = modeleMLP_optimise.predict(F_test)
indices_erreurs = np.where(y_pred_final != y_test)[0]
print("Nombre d'erreurs :", len(indices_erreurs))

for i in indices_erreurs[:10]:  # On affiche les 10 premières erreurs
    img = convertir_image(X_test_raw[i])
    vrai = label_names[y_test[i]].decode()
    predit = label_names[y_pred_final[i]].decode()

    plt.imshow(img)
    plt.title(f"Vrai : {vrai} / Prédit : {predit}")
    plt.axis("off")
    plt.show()

# %% [markdown]
# Phase 2 : Analyse des Classes les plus souvent confondues dans notre modele.

# %%
matrice = confusion_matrix(y_test, y_pred_final)

disp = ConfusionMatrixDisplay(matrice)
disp.plot()
plt.show()

classes_uniques = np.unique(y_test)

print("\nClasses les plus souvent confondues :\n")
for i in range(matrice.shape[0]):
    vrai = label_names[classes_uniques[i]].decode()
    predit = label_names[classes_uniques[np.argmax(matrice[i])]].decode()
    print(f"Classe {vrai} souvent confondue avec {predit}")

# %% [markdown]
# Phase 3 : Correction à apporté à notre modele.
#
# Ici on a decidé d'ajuster un peu nos hyperparametre.

# %%
parametres = {'modele__hidden_layer_sizes': [(50,), (100,), (150,)],
              'modele__activation': ['relu', 'tanh']}

grille_mlp = GridSearchCV(modeleMLP, parametres, cv = 3 )

grille_mlp.fit(F_train, regroup_label)
modele_ameliore = grille_mlp.best_estimator_

score_ameliore = modele_ameliore.score(F_test, y_test)
print("Score après amélioration :", score_ameliore)

# %% [markdown]
# Phase 4 : COMPARAISON ET ANALYSE CRITIQUE.

# %%
print("le score de depart pour le MLPOptimiser :", score_mlp)
print("le score après amelioration :", score_ameliore)

scores = [score_mlp, score_ameliore]
labels = ['Avant amelioration', 'Apres amelioration']

plt.figure(figsize=(15,5))
plt.bar(labels, scores, color=['green', 'yellow'])
plt.ylabel("l'accuracy")
plt.title("Comparaison des performances du MLP avant et apres amelioration")
plt.ylim(min(scores) - 0.005, max(scores) + 0.005)
plt.show()

# %% [markdown]
# ANALYSE : La comparaison des scores montre que le modèle avant amélioration obtient une performance de 0.3995, tandis que le modèle après ajustement des hyperparamètres atteint 0.4045.
#
# Cette légère progression du score montre que l’ajustement des hyperparamètres améliore modestement la capacité du modèle
